# %% [markdown]
# # # Pandas Numpy Sklearn: Introduction
# #
# # This notebook demonstrates approaches to implement Pandas Numpy Sklearn

# %%
import pandas as pd
import numpy as np

# Creating a one-Dimensional labeled Array using pd.series()
s = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
# Creating a DataFrame of size 50 rows x 50 Columns
df = pd.DataFrame(np.random.randn(50, 50), columns=[f'Col{i}' for i in range(1, 51)])
df.head()
# Out:
#        Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 0  0.593068 -0.393465  0.325461 -0.475751 -1.444571  1.173512 -0.227429
# 1 -0.203259  0.666310  1.305765 -0.928911 -0.601532 -0.312496 -1.038998
# 2  0.147648  0.479250 -0.150084 -0.209586 -0.446637  1.526317  0.273975
# 3 -0.975803 -0.994739 -0.436578 -0.685336 -0.533462  0.721447  0.962618
# 4 -0.255866 -0.108918 -1.003050  0.015543 -0.618109  1.326292  0.747506
#
#        Col8      Col9     Col10  ...     Col41     Col42     Col43     Col44  \
# 0  0.211208  0.317136  0.482397  ... -0.668106 -1.103892 -1.202117  0.280104
# 1  1.101173  0.730454 -0.413722  ...  1.352370  0.032621 -0.436142  0.586265
# 2 -0.600064 -0.582241 -1.286009  ... -0.969966 -0.567235  0.112102  1.561410
# 3  0.293564 -1.145898 -0.358353  ... -0.292306 -0.022648  0.218446  0.595643
# 4 -0.121156 -0.744049  0.550821  ...  0.638260  0.864862 -0.374351  0.389607
#
#       Col45     Col46     Col47     Col48     Col49     Col50
# ...

# %%
# Adding a new column with automatic labels
df['Label'] = [f'Row{i}' for i in range(1, 51)]
df[['Label']].head()
# A new column label is added to uniquely identify each row
# Out:
#   Label
# 0  Row1
# 1  Row2
# 2  Row3
# 3  Row4
# 4  Row5

# %%
# Understnad df.describe() and ds.info()
df.describe()
# It gives Summary of statisticals
# Out:
#             Col1       Col2       Col3       Col4       Col5       Col6  \
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    0.181688  -0.251578  -0.000456  -0.232500  -0.013799   0.055214
# std     0.930933   1.083735   0.922927   0.915969   1.036579   1.044482
# min    -2.175112  -2.906173  -2.084582  -2.425745  -2.716877  -2.532138
# 25%    -0.274644  -0.917941  -0.529770  -0.933642  -0.622693  -0.679385
# 50%     0.117697  -0.226103  -0.076194  -0.206817   0.025638  -0.026312
# 75%     0.839141   0.424365   0.421246   0.279691   0.794856   0.702498
# max     2.108674   2.102809   1.978276   1.682880   2.070467   2.280944
#
#             Col7       Col8       Col9      Col10  ...      Col41      Col42  \
# count  50.000000  50.000000  50.000000  50.000000  ...  50.000000  50.000000
# mean    0.193429   0.134085  -0.148598  -0.158634  ...  -0.124960   0.068685
# std     1.042233   1.068201   0.977484   0.984688  ...   1.176626   0.976375
# ...

# %%
df.info()
# Provide Data type , null values and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 51 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    50 non-null     float64
#  1   Col2    50 non-null     float64
#  2   Col3    50 non-null     float64
#  3   Col4    50 non-null     float64
#  4   Col5    50 non-null     float64
#  5   Col6    50 non-null     float64
#  6   Col7    50 non-null     float64
#  7   Col8    50 non-null     float64
#  8   Col9    50 non-null     float64
#  9   Col10   50 non-null     float64
#  10  Col11   50 non-null     float64
#  11  Col12   50 non-null     float64
#  12  Col13   50 non-null     float64
#  13  Col14   50 non-null     float64
#  14  Col15   50 non-null     float64
#  15  Col16   50 non-null     float64
#  16  Col17   50 non-null     float64
#  17  Col18   50 non-null     float64
#  18  Col19   50 non-null     float64
#  19  Col20   50 non-null     float64
# ...

# %%
# Top 5 rows
df.head()
# Out:
#        Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 0 -1.064466  0.917920 -1.090284 -0.250995  1.367802  1.167107  0.512175
# 1 -1.176914  1.298758 -0.581549 -0.138803 -0.878577 -0.156816 -1.735724
# 2  0.075381 -1.415154 -0.657180 -0.742012  0.626342 -1.132080  0.873756
# 3 -0.398917 -0.715497 -2.968080  1.829386 -0.185692  0.349115 -0.091326
# 4  0.107760 -0.310760 -1.193148 -0.832159  0.041256 -1.390451 -1.354992
#
#        Col8      Col9     Col10  ...     Col42     Col43     Col44     Col45  \
# 0  0.599903 -0.680452  0.750740  ...  0.287351  1.017371  1.352103  1.366264
# 1  0.667016 -0.287442  0.373504  ... -1.239633 -1.434156 -0.559591 -1.515230
# 2  0.497305  1.940859  0.588978  ...  0.034449 -1.150394 -0.139055  0.452860
# 3 -0.783679 -0.306374 -0.723399  ...  0.298416  1.209418  0.790433 -0.711034
# 4  0.024631  1.690229 -1.414761  ... -0.716097 -1.161399 -0.224044 -0.754113
#
#       Col46     Col47     Col48     Col49     Col50  Label
# ...

# %%
# Last 5 rows
df.tail()
# Out:
#         Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 45  1.209581 -0.872257 -0.155084  0.041752  0.757401  0.104127  0.542847
# 46  0.142355  0.745604 -0.541927  2.206999 -0.025814 -0.296241  0.906909
# 47  0.023304 -0.095810  0.899887 -0.520800  1.279632 -0.797243 -0.333447
# 48  1.870672  0.088484  0.664625  0.060749 -1.426461  0.227717 -0.411692
# 49  0.976955 -0.346965 -0.954288  1.280414 -0.103392 -1.805933  0.458237
#
#         Col8      Col9     Col10  ...     Col42     Col43     Col44     Col45  \
# 45  1.065020  0.269635  0.253655  ...  0.696460 -2.566725  1.168413  1.567590
# 46 -1.318142  0.249899  0.298361  ... -0.105319  0.489369 -0.308692  0.875646
# 47  0.336786  0.023539 -0.093283  ... -1.464769  0.280127  0.031083 -0.274714
# 48  0.845217  1.604857 -0.978237  ...  0.443969 -1.391997 -0.082098  1.534549
# 49  1.313875  1.462998  0.054228  ... -0.122392  0.568676  0.169786  0.244227
#
# ...

# %%
# It will shows (rows, columns) colunt
df.shape
# Out:
# (50, 51)

# %%
# Convert to NumPy array
array_data = df.to_numpy()

# Transpose DataFrame
transposed_df = df.T

# Sort by index 
sorted_df = df.sort_index()

# Sort by values in Col1
sorted_values_df = df.sort_values(by='Col1')

# %%
# Creating a new DataFrame df2
df2 = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8],
    'C': [9, 10, 11, 12]
}, index=['row1', 'row2', 'row3', 'row4'])

# loc: label-based selection
df2.loc['row2']
# Out:
# A     2
# B     6
# C    10
# Name: row2, dtype: int64

# %%
# iloc: integer position-based selection
df2.iloc[1]
# Out:
# A     2
# B     6
# C    10
# Name: row2, dtype: int64

# %%
# Introducing missing values
df2.loc['row2', 'B'] = np.nan

# Drop rows with NaN
print(df2.dropna())

# Fill NaN with a value
print(df2.fillna(0))

# Check where NaN exists
print(df2.isna())
# Out:
#       A    B   C
# row1  1  5.0   9
# row3  3  7.0  11
# row4  4  8.0  12
#       A    B   C
# row1  1  5.0   9
# row2  2  0.0  10
# row3  3  7.0  11
# row4  4  8.0  12
#           A      B      C
# row1  False  False  False
# row2  False   True  False
# row3  False  False  False
# row4  False  False  False

# %%
# Introduce duplicate rows
df3 = pd.DataFrame({'A': [1, 2, 2, 3], 'B': [4, 5, 5, 6]})

# Check duplicates
print(df3.duplicated())

# Drop duplicate rows
print(df3.drop_duplicates())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool
#    A  B
# 0  1  4
# 1  2  5
# 3  3  6

# %%
# Example DataFrame
df4 = pd.DataFrame({'Color': ['Red', 'Blue', 'Green', 'Red']})

# One-hot encoding
encoded_df = pd.get_dummies(df4, columns=['Color'])
print(encoded_df)
# Out:
#    Color_Blue  Color_Green  Color_Red
# 0       False        False       True
# 1        True        False      False
# 2       False         True      False
# 3       False        False       True

# %%
# Select rows where A > 0
print(df2[df2['A'] > 0])
# Out:
#       A    B   C
# row1  1  5.0   9
# row2  2  NaN  10
# row3  3  7.0  11
# row4  4  8.0  12

# %%
# Concatenate two DataFrames
df5 = pd.DataFrame({'A': [1, 2]})
df6 = pd.DataFrame({'A': [3, 4]})
concat_df = pd.concat([df5, df6])
print(concat_df)
# Out:
#    A
# 0  1
# 1  2
# 0  3
# 1  4

# %%
# Correlation matrix
df.select_dtypes(include='number').corr()
# Out:
#            Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# Col1   1.000000 -0.301081  0.110791  0.087273 -0.112559 -0.211046  0.221168
# Col2  -0.301081  1.000000 -0.086359  0.152787 -0.012840  0.102314 -0.244885
# Col3   0.110791 -0.086359  1.000000 -0.104286  0.012663  0.068637 -0.046769
# Col4   0.087273  0.152787 -0.104286  1.000000 -0.158936  0.169671  0.068117
# Col5  -0.112559 -0.012840  0.012663 -0.158936  1.000000 -0.062566  0.254371
# Col6  -0.211046  0.102314  0.068637  0.169671 -0.062566  1.000000  0.182714
# Col7   0.221168 -0.244885 -0.046769  0.068117  0.254371  0.182714  1.000000
# Col8   0.282243 -0.097909 -0.039405 -0.067675  0.185554 -0.183360  0.140168
# Col9   0.193611  0.001204 -0.170220  0.019323  0.001260 -0.222083  0.148396
# Col10 -0.088419  0.081532 -0.022529 -0.087978  0.147135  0.088236  0.166150
# Col11 -0.150532 -0.079403  0.020225 -0.069592 -0.133233  0.150146  0.180119
# ...
